# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

file = '/content/drive/MyDrive/SUH LAB/0109_1_1 con.txt'

#df = pd.read_csv(file)

df = pd.DataFrame(np.loadtxt(file))
df
# Out:
#              0      1
# 0        0.000    0.0
# 1        0.000    0.0
# 2        0.000    0.0
# 3        0.000    0.0
# 4        0.000    0.0
# ...        ...    ...
# 2004  5792.115  646.0
# 2005  5794.175  646.6
# 2006  5796.234  642.6
# 2007  5798.292  644.2
# 2008  5800.350  639.4
#
# [2009 rows x 2 columns]

# %%
df.columns = ["w", "i"]
print(df)
# Out:
#              w      i
# 0        0.000    0.0
# 1        0.000    0.0
# 2        0.000    0.0
# 3        0.000    0.0
# 4        0.000    0.0
# ...        ...    ...
# 2004  5792.115  646.0
# 2005  5794.175  646.6
# 2006  5796.234  642.6
# 2007  5798.292  644.2
# 2008  5800.350  639.4
#
# [2009 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

df_2 = df.iloc[354:947]

plt.figure()
plt.plot(df_2['w'],df_2['i'])
plt.show()
