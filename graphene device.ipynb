# %%
import pandas as pd
import numpy as np

# %%
file = '/content/drive/MyDrive/SUH LAB/KSH-Graphene device/2. graphene device _ fe _ IV'
file_2 ='/content/drive/MyDrive/SUH LAB/KSH-Graphene device/1. graphene device _ fe _ Vg swep'
file_3 = '/content/drive/MyDrive/SUH LAB/KSH-Graphene device/3. graphene device _ fe _ Vg swep'
file_4 = '/content/drive/MyDrive/SUH LAB/KSH-Graphene device/4. graphene device _ fe _ Vg swep'
file_5 = '/content/drive/MyDrive/SUH LAB/KSH-Graphene device/5. graphene device _ fe _ Vg swep'
file_6 = '/content/drive/MyDrive/SUH LAB/KSH-Graphene device/6. graphene device _ fe _ Vg swep'
# 데이터프레임 생성
df = pd.read_csv (file, header= None, sep = '\t',
                  names = ['time','Vsd','Isd','R','Vg','Ileak'])
df_2 = pd.read_csv (file_2, header= None, sep = '\t',
                  names = ['time','Vg','Ileak','Vsd','Isd','R'])
df_3 = pd.read_csv (file_3, header= None, sep = '\t',
                  names = ['time','Vg','Ileak','Vsd','Isd','R'])
df_4 = pd.read_csv (file_4, header= None, sep = '\t',
                  names = ['time','Vg','Ileak','Vsd','Isd','R'])
df_5 = pd.read_csv (file_5, header= None, sep = '\t',
                  names = ['time','Vg','Ileak','Vsd','Isd','R'])
df_6 = pd.read_csv (file_6, header= None, sep = '\t',
                  names = ['time','Vg','Ileak','Vsd','Isd','R'])
print(df_5)
print(df_6)
# Out:
#            time   Vg         Ileak   Vsd       Isd         R
# 0      5.970557  0.0 -1.048343e-10  0.01  0.000020  489.6927
# 1      8.343488  1.0 -9.405171e-11  0.01  0.000020  492.3639
# 2      8.731995  2.0 -8.708442e-11  0.01  0.000020  495.8111
# 3      9.122864  3.0 -8.036646e-11  0.01  0.000020  499.1504
# 4      9.511416  4.0 -7.924731e-11  0.01  0.000020  502.3253
# ..          ...  ...           ...   ...       ...       ...
# 713  290.568000  4.0 -1.524010e-10  0.01  0.000020  496.7549
# 714  290.968500  3.0 -1.548933e-10  0.01  0.000020  493.6248
# 715  291.367500  2.0 -1.546937e-10  0.01  0.000020  490.4249
# 716  291.766600  1.0 -1.574387e-10  0.01  0.000021  487.5556
# 717  292.168600  0.0 -1.556048e-10  0.01  0.000021  484.6081
#
# [718 rows x 6 columns]
#           time   Vg         Ileak   Vsd       Isd         R
# 0     10.82050  0.0 -1.074816e-10  0.01  0.000021  487.0835
# 1     13.20247  1.0 -9.496912e-11  0.01  0.000020  490.1113
# ...

# %%
import matplotlib.pyplot as plt

# Plotting Isd with lines and markers
plt.plot(df['Vsd'], df['Isd'], label='Isd',  linestyle='-', color='darkgreen', linewidth=0.3)

# Adding labels and title
plt.xlabel('Vsd  (V)')
plt.ylabel('Isd (A)')
plt.title('Isd vs Vsd with Lines and Markers')
plt.legend()

# Display the plot
plt.show()

# %%
# Plotting Isd with lines and markers
plt.plot(df_2['Vg'], df_2['Isd'], label='Isd', linestyle='-', color='darkgreen', linewidth=0.3)

# Adding labels and title
plt.xlabel('Vg (V) ')
plt.ylabel('Isd (A)')
plt.title('Isd vs Vg with Lines and Markers')
plt.legend()

# Display the plot
plt.show()

# Plotting Isd with lines and markers
plt.plot(df_3['Vg'], df_3['Isd'], label='Isd',  linestyle='-', color='darkgreen', linewidth=0.3)

# Adding labels and title
plt.xlabel('Vg (V) ')
plt.ylabel('Isd (A) ')
plt.title('Isd vs Vg with Lines and Markers')
plt.legend()

# Display the plot
plt.show()

# Plotting Isd with lines and markers
plt.plot(df_4['Vg'], df_4['Isd'], label='Isd', linestyle='-', color='darkgreen', linewidth=0.3)

# Adding labels and title
plt.xlabel('Vg (V) ')
plt.ylabel('Isd (A) ')
plt.title('Isd vs Vg with Lines and Markers')
plt.legend()

# Display the plot
plt.show()

# Plotting Isd with lines and markers
plt.plot(df_5['Vg'], df_5['Isd'], label='Isd', linestyle='-', color='darkgreen', linewidth=0.3)

# Adding labels and title
plt.xlabel('Vg (V) ')
plt.ylabel('Isd (A) ')
plt.title('Isd vs Vg with Lines and Markers')
plt.legend()

# Display the plot
plt.show()

# Plotting Isd with lines and markers
plt.plot(df_6['Vg'], df_6['Isd'], label='Isd',  linestyle='-', color='darkgreen', linewidth=0.3)

# Adding labels and title
plt.xlabel('Vg (V) ')
plt.ylabel('Isd (A)')
plt.title('Isd vs Vg with Lines and Markers')
plt.legend()

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# 파일 경로 지정
df_6 = '/content/drive/MyDrive/SUH LAB/KSH-Graphene device/6. graphene device _ fe _ Vg swep'

# 파일을 읽어와 데이터프레임으로 저장
df_6 = pd.read_csv (file_6, header= None, sep = '\t',
                  names = ['time','Vg','Ileak','Vsd','Isd','R'])

# 처음 20행을 추출하여 새로운 데이터프레임 생성
df_6_1 = df_6.iloc[0:20]
df_6_2 = df_6.iloc[21:61]
df_6_3 = df_6.iloc[62:122]
df_6_4 = df_6.iloc[123:203]
df_6_5 = df_6.iloc[205:304]
df_6_6 = df_6.iloc[305:425]
df_6_7 = df_6.iloc[426:566]
df_6_8 = df_6.iloc[568:728]

# 결과 확인
print(df_6_6)
# Out:
#          time   Vg         Ileak   Vsd       Isd         R
# 305  132.7899  0.0 -1.385636e-10  0.01  0.000021  485.8442
# 306  133.1903  1.0 -1.194384e-10  0.01  0.000020  488.9332
# 307  133.5902  2.0 -1.130811e-10  0.01  0.000020  492.0744
# 308  133.9901  3.0 -1.014288e-10  0.01  0.000020  495.4098
# 309  134.3847  4.0 -9.934301e-11  0.01  0.000020  498.7270
# ..        ...  ...           ...   ...       ...       ...
# 420  178.7817  5.0 -1.524014e-10  0.01  0.000020  500.9054
# 421  179.1751  4.0 -1.534185e-10  0.01  0.000020  497.5565
# 422  179.5656  3.0 -1.515362e-10  0.01  0.000020  494.4427
# 423  179.9613  2.0 -1.516930e-10  0.01  0.000020  491.3747
# 424  180.3719  1.0 -1.563197e-10  0.01  0.000020  488.2755
#
# [120 rows x 6 columns]

# %%
# Plotting Isd with lines and markers
plt.plot(df_6_1['Vg'], df_6_1['Isd'], label='Isd',  linestyle='-', color='red', linewidth=0.5)
plt.plot(df_6_2['Vg'], df_6_2['Isd'], label='Isd',  linestyle='-', color='blue', linewidth=0.5)
plt.plot(df_6_3['Vg'], df_6_3['Isd'], label='Isd',  linestyle='-', color='green', linewidth=0.5)
plt.plot(df_6_4['Vg'], df_6_4['Isd'], label='Isd',  linestyle='-', color='pink', linewidth=0.5)
plt.plot(df_6_5['Vg'], df_6_5['Isd'], label='Isd',  linestyle='-', color='purple', linewidth=0.5)
plt.plot(df_6_6['Vg'], df_6_6['Isd'], label='Isd',  linestyle='-', color='gray', linewidth=0.5)
plt.plot(df_6_7['Vg'], df_6_7['Isd'], label='Isd',  linestyle='-', color='skyblue', linewidth=0.5)
plt.plot(df_6_8['Vg'], df_6_8['Isd'], label='Isd',  linestyle='-', color='brown', linewidth=0.5)

# Adding labels and title
plt.xlabel('Vg (V) ')
plt.ylabel('Isd (A)')
plt.title('Isd vs Vg with Lines and Markers')
plt.legend()

# Display the plot
plt.show()
